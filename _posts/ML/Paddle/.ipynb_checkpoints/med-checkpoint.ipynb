# %% [markdown]
# # AI Studio医学影像项目集锦

# %% [markdown]
# 随着深度学习计算机视觉技术的快速发展，越来越多的行业开始利用这一强大的技术执行一些比较简单和重复的任务，医学影像方向也不例外。这篇Notebook整理了AI Studio上有关医学影像的项目，希望能帮助大家了解医学影像方向的研究都做些什么。同时也起到抛砖引玉的作用，激发大佬们的创意！

# %% [markdown]
# 项目按照任务类型大致分类，每个类别中按照发布时间由新到旧排序。项目都是笔者自己收集的所以大概率会有遗漏，欢迎大佬们在评论区留言补充！

# %% [markdown]
# # 分割项目
# 分割可以看作是对图像中每一个像素进行分类的过程，医学影像通常对目标边缘和体积比较关注，分割类型的任务是最多的。

# %% [markdown]
# ## [PaddleSeg与放射临床工作的小结合(Paddle2.0)](https://aistudio.baidu.com/aistudio/projectdetail/1438719)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# 在冠状面CT中对肺和心脏进行分割，并分别计算其宽度，得出心胸比
# ![](https://ai-studio-static-online.cdn.bcebos.com/4fd575d1c7974685bf0814c451dcb3b84634088e0ff749dfb520731030f7ea20)

# %% [markdown]
# ## [CT影像数据DICOM与图像分割(paddle2.0)](https://aistudio.baidu.com/aistudio/projectdetail/1324220)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# 医学影像特殊的数据格式对初学者可谓非常不友好！这个项目介绍了医学影像常用的Dicom文件结构，从数据读取和预处理开始，手把手教你如何使用PaddleSeg快速搭建一个肝脏分割pipeline，并通过MIP操作清晰的展示肝脏中的血管。
# ![](data:image/png;base64,...)
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ## [使用飞桨PaddleSeg进行胸部X光肺部分割](https://aistudio.baidu.com/aistudio/projectdetail/1170556)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# 基于PaddleSeg训练一个肺部分割模型，并进行多种可视化。
# ![](data:image/png;base64,...)
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ## [基于PaddleSeg的眼底血管分割——使用飞桨助力医学影像分析]()
# by [Mr.郑先生_](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/147378)
#
# 一些眼科或心脑血管疾病会对眼底血管造成影像，导致出血/形变等症状。从检眼镜拍摄的眼底照片中分割出血管，并对其形态进行分析可以诊断一些疾病。本项目基于PaddleSeg实现一个眼底血管分割模型，过程详细，容易上手。
# ![](https://ai-studio-static-online.cdn.bcebos.com/021226eedc78495283a1014c5a37c9e0e325fa4f769449e395a1a25e52b17623)

# %% [markdown]
# ## [基于PaddleSeg的新冠病灶分割](https://aistudio.baidu.com/aistudio/projectdetail/528293)
# by [代码生成器](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/33061)
#
# 在对新冠肺炎患者病情严重程度进行分析的过程中，胸腹部CT扫描中新冠病灶体积占肺部总容积的比例是一个可以辅助医生作出判断的数量指标。本项目基于PaddleSeg训练了一个新冠病灶分割模型，并最终达到89%的IOU。
# ![](https://ai-studio-static-online.cdn.bcebos.com/196fc77f5fee49688dbedaf2536bd294694e9cddb569435592fec0fdfefe8919)
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/3614438eea744c5bbe7ec6f64a31a39cad092ad56327426f9dd02f3cafeea72e)

# %% [markdown]
# ## [基于Paddle的肝脏CT影像分割](https://aistudio.baidu.com/aistudio/projectdetail/250994)
# by [代码生成器](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/33061)
#
# 肝脏及肝脏肿瘤体积这两个指标在肝移植，肝切等多种治疗流程中都可以给医生提供参考。这个项目使用静态图API在LiTS数据集上训练了一个肝脏及肝脏肿瘤分割的Unet模型。
# ![](https://ai-studio-static-online.cdn.bcebos.com/e4657943400b43c8b7ad28514598959e95b8ae13edf34c3db7376767a52d3dcb)
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/50b79f43d0344facb8af970f0d9727e78ec12a5a6a274bd2b647bb76b961100a)

# %% [markdown]
# ## [基于PaddlePaddle的肝脏CT影像分割(Unet动态版)](https://aistudio.baidu.com/aistudio/projectdetail/409066)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# 静态图编程比较复杂，吖查大佬在静态图项目的基础上进行了修改。使用动态图搭建网络的写法更加简单直观。

# %% [markdown]
# ## [PaddleHub 肺炎CT影像分析](https://aistudio.baidu.com/aistudio/projectdetail/289819)
# by [飞桨PaddleHub](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/79927)
#
# 百度和连心医疗联合出品的肺炎CT影像分析模型。可以对肺部和肺炎病灶进行分割，结合后处理代码可以分析输出肺部病灶的数量、体积、病灶占比等全套定量指标。
# ![](data:image/png;base64,...)

# %% [markdown]
# # 分类项目

# %% [markdown]
# ## [基于Paddleclas的新冠肺炎CT分类](https://aistudio.baidu.com/aistudio/projectdetail/463184)
# by [代码生成器](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/33061)
#
# 本项目使用PaddleClas对健康，患有普通肺炎和新冠肺炎三种类别的CT冠状面扫描进行分类，并在测试集上达到了97%的分类准确率。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/00faf7de665d4eb1b73b4adcaba2c7e8bd800f5cf9284ddbba627c5a6b087b99)

# %% [markdown]
# # 检测项目

# %% [markdown]
# ## [PaddleDetection手部X光关键点检测(快速得到成果)](https://aistudio.baidu.com/aistudio/projectdetail/464837)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# 骨龄计算是放射工作中通过在手部X光图片测量青少年的真实发育年龄的一种重要手段。是一项非常耗时、耗精力的临床工作。本项目使用PaddleDetection在手部CT扫描中检测用于骨龄计算的关节，可以快速得到结果，为下一步骨龄的检测打下基础。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/e87fff0fc55046beb0f8ddabf4a20172c9877c2c40144ffc92edc42116e709e7)

# %% [markdown]
# ## [骨龄计算综合应用：使用飞桨让医生再腾出10分钟](https://aistudio.baidu.com/aistudio/projectdetail/1485230)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# 在使用Yolo网络检测出手部的所有关节后，根据关节的相对位置筛选出计算骨龄关注的部分关节。使用ResNet50网络对关节所属的发育等级进行分类，并最终根据公式计算出骨龄。
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ## [基于 CT 影像的结直肠息肉检测](https://aistudio.baidu.com/aistudio/projectdetail/506571)
# by [goog](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/276981)
#
# 结直肠息肉是结直肠癌的早期病变，而结直肠癌是最常见的恶性肿瘤之一，Cancer Statistics 2020 统计数据显示，结直肠癌在美国的发病率和致死率在所有癌症中位列第三。本项目使用动态图API搭建YoloV3网络，在CT扫描中对结直肠息肉进行检测。

# %% [markdown]
# ## 生成项目

# %% [markdown]
# ## [通过Pix2Pix把MR的T1图像变T2(内有paddleGAN）](https://aistudio.baidu.com/aistudio/projectdetail/1253623)
# by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
#
# T1和T2是两种不同核磁共振扫描流程，从原理上讲区别比较复杂。可以大致认为在T1图中一般脂肪含量高的组织比较亮，在T2图中一般水含量高的组织信号高，二者侧重不同。本项目用手动搭建的Pix2Pix模型和PaddleGAN两种方式，从T1图像直接生成其对应的T2图像。

# %% [markdown]
# # 数据集项目
# 在医学影像领域数据通常都不太好获取，一些数据集列表项目可能可以帮助大家更快地找到自己需要的数据集。

# %% [markdown]
# ## [医学影像数据集集锦](https://aistudio.baidu.com/aistudio/projectdetail/462184)
# by [代码生成器](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/33061)
#
# 包含20+方向的70+医学影像数据集，并持续更新中。如果需要的数据集不在列表中，可以[在项目Github上开Issue](https://github.com/linhandev/dataset/issues/new?assignees=linhandev&labels=%E6%96%B0%E5%A2%9E%E6%95%B0%E6%8D%AE%E9%9B%86&template=-----.md&title=%5B%E6%96%B0%E5%A2%9E%5D+%E6%B7%BB%E5%8A%A0%E6%96%B0%E6%95%B0%E6%8D%AE%E9%9B%86%E3%80%80xx)，提供免费代下！
# ![image.png](attachment:3317432c-37e0-4153-9bb8-4be19009f8d9.png)

# %% [markdown]
# ## [胸部\肺部ct数据集](https://aistudio.baidu.com/aistudio/projectdetail/431782)
# by [自尊心3](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/218586)
#
# 包含20个左右胸肺部扫描数据集。

# %%
by [代码生成器](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/33061)
by [吖吖查](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/181096)
